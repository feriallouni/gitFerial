# %% [markdown]
# <a href="https://colab.research.google.com/github/feriallouni/gitFerial/blob/master/NBAwebscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importer les packages
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
#collecter le contenu du lien url 
url='https://www.basketball-reference.com/leagues/NBA_2021_per_game.html'

# %%
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/bbr/build" itemscope itemtype="https://schema.org/WebSite" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/202203151" />\n    <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://quantcast.mgr.consensu.org\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \'/choice.js\')\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\
# ...

# %%
#utiliser beautifulsoup
soup=BeautifulSoup(page.content,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202203151" rel="dns-prefetch"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
#     (function() {
# 	var host = window.location.hostname;
# 	var element = document.createElement('script');
# 	var firstScript = document.getElementsByTagName('script')[0];
# 	var url = 'https://quantcast.mgr.consensu.org'
# 	    .concat('/choice/', 'XwNYEpNeFfhfr', '/', host, '/choice.js')
# 	var uspTries = 0;
# 	var uspTriesLimit = 3;
# 	element.async = true;
# 	element.type = 'text/javascript';
# 	element.src = url;
# ...

# %%
tableau=soup.find_all(class_='full_table')
tableau

# %%
joueurs=[]
for i in tableau
# Out:
#   File "<ipython-input-9-c7680be996d2>", line 2
#     for i in tableau
#                     ^
# SyntaxError: invalid syntax

# %%
tableau[1]

# %%
joueur=[]
for j in tableau [1].find_all('td'):
  print(j)
  joueur.append(j.text)
print(joueur)

# %%
joueurs=[]
for i in range(len(tableau)):
  joueur=[]
  for j in tableau [i].find_all('td'):
    joueur.append(j.text)
  joueurs.append(joueur)
print(joueurs)

# %%
joueurs[2]

# %%
head=soup.find(class_='thead')
column_name=[head.text for item in head][0]
column_name

# %%
column_name_clean=column_name.split('\n')[2:-1]
column_name_clean

# %%
df=pd.DataFrame(joueurs,columns=column_name_clean).set_index('Player')
df

# %%
df.shape

# %%
df['Age'].value_counts()

# %%
 df['Age']=df['Age'].astype(str).astype(int)
 df.info()

# %%
df['Age'].mean()

# %%
df['Age'].describe()

# %%
print(joueurs,df['Age'])

# %%
df.to_csv('nba.csv',index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Y=df.Age
X=df.index
plt.plot(X,Y,color='g')
